# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaPatel03/googleplatstoreEDA/blob/main/Google_Play_Store_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import of Liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import of Data File
data=pd.read_csv('4-googleplaystore.csv')

# %%
#Question 1
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018             1.00.00
# ...

# %% [markdown]
# It shows the top 5 rows of the dataset which will help us in analyse that what type of data is there and which columns are there.

# %%
#Question 2
data.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                   1
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %% [markdown]
# It shows the last 3 rows of the dataset.

# %%
#Question 3
data.shape
print('Number of rows',data.shape[0])
print('Number of column',data.shape[1])
# Out:
# Number of rows 10841
# Number of column 13

# %% [markdown]
# It shows the total number of rows and columns.

# %%
#Question 4
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# It gives us the information about the data in the dataset that what are the data types and how many non-ull data is there with it's respective column .

# %%
#Question 5
data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# It shows the outcomes of some of the statistical and aggregate functions.

# %%
#Question 6-
len(data[data['App'].str.contains('Astrology',case = False)])
# Out:
# 3

# %% [markdown]
# It shows that how many app contains the word 'astrology' irrespective of how it is entered in the dataset.

# %%
#Question 7
data['Rating'].mean()
# Out:
# np.float64(4.193338315362443)

# %% [markdown]
# It calculates the average rating of the apps which is given to them on google playstore.

# %%
#Question 8
data['Category'].nunique()
# Out:
# 34

# %% [markdown]
# It calculates the total number of unique categories that each app can have.

# %%
#Question 9
data.groupby('Category')['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %%
p1 = data.groupby('Category')['Rating'].mean().sort_values(ascending=False).head(5).drop('1.9')
p1 = p1.reset_index()
p1.plot(kind = 'scatter',x = 'Category',y = 'Rating')
plt.show()

# %% [markdown]
# It shows the average rating each category have from highest to lowest.

# %%
#Question 10
len(data[data['Rating'] == 5.0])
# Out:
# 274

# %% [markdown]
# It shows that how many apps has received a rating of 5.0 on google playstore.

# %%
#question 11
data[data['Reviews']=='3.0M']
data['Reviews']=data['Reviews'].replace('3.0M',3.0)
data['Reviews']=data['Reviews'].astype('float')
data['Reviews'].dtype
data['Reviews'].mean()
# Out:
# np.float64(444111.9265750392)

# %%
#Question 12
data['Type'].value_counts().reset_index()
# Out:
#    Type  count
# 0  Free  10039
# 1  Paid    800
# 2     0      1

# %% [markdown]
# It shows which type of apps are mostly available on the google playstore.

# %%
p1 = data['Type'].value_counts().reset_index().drop(2)
p1.plot(kind = 'bar')
plt.show()

# %%
#Question 13
data.groupby('App')['Reviews'].max().sort_values(ascending=False).head(10)
# Out:
# App
# Facebook                                              78158306.0
# WhatsApp Messenger                                    69119316.0
# Instagram                                             66577446.0
# Messenger – Text and Video Chat for Free              56646578.0
# Clash of Clans                                        44893888.0
# Clean Master- Space Cleaner & Antivirus               42916526.0
# Subway Surfers                                        27725352.0
# YouTube                                               25655305.0
# Security Master - Antivirus, VPN, AppLock, Booster    24900999.0
# Clash Royale                                          23136735.0
# Name: Reviews, dtype: float64

# %%
t1 = data.groupby('App')['Reviews'].max().sort_values(ascending=False).head(10)
t2 = pd.to_numeric(t1)
t2.plot(kind = 'bar')
plt.show()

# %% [markdown]
# It shows that which app has got the most number of reviews on the google playstore but we sholud not confuse it with number of positive reviews.

# %%
#Question 14
index=data['Reviews'].sort_values(ascending=False).head().index
data.iloc[index]['App']
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %%
#Question 15
data.groupby('Type')['Rating'].mean().tail(2)
# Out:
# Type
# Free    4.186203
# Paid    4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# It shows that which type of app has got better average rating and we can see that even if the apps are charging for the services but the average rating of the sevices is better than those of the free apps which indicates that they are delivering the experience that people has paid for.

# %%
t1 = data.groupby('Category')['Reviews'].max().sort_values(ascending=False).head(10)
t2 = pd.to_numeric(t1)
plt.figure(figsize=(13, 6))
ax = t2.plot(kind = 'barh',color = 'g')
plt.bar_label(ax.containers[0], padding=1, fontweight='bold')
plt.show()
